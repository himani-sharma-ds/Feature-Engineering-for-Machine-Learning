# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\Himani Sharma\OneDrive\Desktop\HDFC loan dataset (2)\HDFC loan dataset\Loan payments data.csv")

# %%
dataset.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.fillna(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 0     10/7/2016   9/14/2016 19:31           10.0   45  High School or Below
# 1     10/7/2016    10/7/2016 9:00           10.0   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58           10.0   33              Bechalor
# 3     9/22/2016   9/22/2016 20:00           10.0   27               college
# 4     10/8/2016   9/23/2016 21:36           10.0   28               college
# ..          ...               ...            ...  ...                   ...
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male
#
# [500 rows x 11 columns]

# %%
# backward filling and forward filling
dataset.fillna(method = "bfill")
# Out:
# C:\Users\Himani Sharma\AppData\Local\Temp\ipykernel_1824\2641276198.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "bfill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 0     10/7/2016   9/14/2016 19:31           76.0   45  High School or Below
# 1     10/7/2016    10/7/2016 9:00           76.0   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58           76.0   33              Bechalor
# 3     9/22/2016   9/22/2016 20:00           76.0   27               college
# 4     10/8/2016   9/23/2016 21:36           76.0   28               college
# ..          ...               ...            ...  ...                   ...
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male
#
# [500 rows x 11 columns]

# %%
dataset.fillna(method = "ffill")
# Out:
# C:\Users\Himani Sharma\AppData\Local\Temp\ipykernel_1824\1261878897.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "ffill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 0     10/7/2016   9/14/2016 19:31            NaN   45  High School or Below
# 1     10/7/2016    10/7/2016 9:00            NaN   50              Bechalor
# 2     10/7/2016   9/25/2016 16:58            NaN   33              Bechalor
# 3     9/22/2016   9/22/2016 20:00            NaN   27               college
# 4     10/8/2016   9/23/2016 21:36            NaN   28               college
# ..          ...               ...            ...  ...                   ...
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male
#
# [500 rows x 11 columns]

# %%
dataset.fillna(method = "bfill",axis = 1)
# Out:
# C:\Users\Himani Sharma\AppData\Local\Temp\ipykernel_1824\1073434981.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "bfill",axis = 1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF      1000    30      9/12/2016
#
#        due_date     paid_off_time past_due_days age             education  \
# 0     10/7/2016   9/14/2016 19:31            45  45  High School or Below
# 1     10/7/2016    10/7/2016 9:00            50  50              Bechalor
# 2     10/7/2016   9/25/2016 16:58            33  33              Bechalor
# 3     9/22/2016   9/22/2016 20:00            27  27               college
# 4     10/8/2016   9/23/2016 21:36            28  28               college
# ..          ...               ...           ...  ..                   ...
# 495  10/11/2016  10/14/2016 19:08           3.0  28  High School or Below
# 496   9/26/2016  10/10/2016 20:02          14.0  26  High School or Below
# 497   9/26/2016   9/29/2016 11:49           3.0  30               college
# 498  11/10/2016  11/11/2016 22:40           1.0  38               college
# 499  10/11/2016  10/19/2016 11:58           8.0  28  High School or Below
#
#      Gender
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male
#
# [500 rows x 11 columns]

# %%
dataset.fillna(method = "ffill",axis = 1)
# Out:
# C:\Users\Himani Sharma\AppData\Local\Temp\ipykernel_1824\2516407657.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "ffill",axis = 1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF      1000    30      9/12/2016
#
#        due_date     paid_off_time    past_due_days age             education  \
# 0     10/7/2016   9/14/2016 19:31  9/14/2016 19:31  45  High School or Below
# 1     10/7/2016    10/7/2016 9:00   10/7/2016 9:00  50              Bechalor
# 2     10/7/2016   9/25/2016 16:58  9/25/2016 16:58  33              Bechalor
# 3     9/22/2016   9/22/2016 20:00  9/22/2016 20:00  27               college
# 4     10/8/2016   9/23/2016 21:36  9/23/2016 21:36  28               college
# ..          ...               ...              ...  ..                   ...
# 495  10/11/2016  10/14/2016 19:08              3.0  28  High School or Below
# 496   9/26/2016  10/10/2016 20:02             14.0  26  High School or Below
# 497   9/26/2016   9/29/2016 11:49              3.0  30               college
# 498  11/10/2016  11/11/2016 22:40              1.0  38               college
# 499  10/11/2016  10/19/2016 11:58              8.0  28  High School or Below
#
#      Gender
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male
#
# [500 rows x 11 columns]

# %%
dataset["past_due_days"]= dataset["past_due_days"].fillna(dataset["past_due_days"].mode()[0])

# %%
dataset["past_due_days"].mode()[0]
# Out:
# np.float64(59.0)

# %%
dataset.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31           59.0   45  High School or Below    male
# 1   10/7/2016 9:00           59.0   50              Bechalor  female
# 2  9/25/2016 16:58           59.0   33              Bechalor  female
# 3  9/22/2016 20:00           59.0   27               college    male
# 4  9/23/2016 21:36           59.0   28               college  female

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   500 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
dataset.select_dtypes(include = "object")
# Out:
#          Loan_ID         loan_status effective_date    due_date  \
# 0    xqd20166231             PAIDOFF       9/8/2016   10/7/2016
# 1    xqd20168902             PAIDOFF       9/8/2016   10/7/2016
# 2    xqd20160003             PAIDOFF       9/8/2016   10/7/2016
# 3    xqd20160004             PAIDOFF       9/8/2016   9/22/2016
# 4    xqd20160005             PAIDOFF       9/9/2016   10/8/2016
# ..           ...                 ...            ...         ...
# 495  xqd20160496  COLLECTION_PAIDOFF      9/12/2016  10/11/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      9/12/2016   9/26/2016
# 497  xqd20160498  COLLECTION_PAIDOFF      9/12/2016   9/26/2016
# 498  xqd20160499  COLLECTION_PAIDOFF      9/12/2016  11/10/2016
# 499  xqd20160500  COLLECTION_PAIDOFF      9/12/2016  10/11/2016
#
#         paid_off_time             education  Gender
# 0     9/14/2016 19:31  High School or Below    male
# 1      10/7/2016 9:00              Bechalor  female
# 2     9/25/2016 16:58              Bechalor  female
# 3     9/22/2016 20:00               college    male
# 4     9/23/2016 21:36               college  female
# ..                ...                   ...     ...
# 495  10/14/2016 19:08  High School or Below    male
# 496  10/10/2016 20:02  High School or Below    male
# 497   9/29/2016 11:49               college    male
# 498  11/11/2016 22:40               college  female
# 499  10/19/2016 11:58  High School or Below    male
#
# [500 rows x 7 columns]

# %%
dataset.select_dtypes(include = "object").isnull()
# Out:
#      Loan_ID  loan_status  effective_date  due_date  paid_off_time  education  \
# 0      False        False           False     False          False      False
# 1      False        False           False     False          False      False
# 2      False        False           False     False          False      False
# 3      False        False           False     False          False      False
# 4      False        False           False     False          False      False
# ..       ...          ...             ...       ...            ...        ...
# 495    False        False           False     False          False      False
# 496    False        False           False     False          False      False
# 497    False        False           False     False          False      False
# 498    False        False           False     False          False      False
# 499    False        False           False     False          False      False
#
#      Gender
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 495   False
# 496   False
# 497   False
# 498   False
# 499   False
#
# [500 rows x 7 columns]

# %%
dataset.select_dtypes(include = "object").isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# effective_date      0
# due_date            0
# paid_off_time     100
# education           0
# Gender              0
# dtype: int64

# %%
dataset.select_dtypes(include = "object").isnull().columns
# Out:
# Index(['Loan_ID', 'loan_status', 'effective_date', 'due_date', 'paid_off_time',
#        'education', 'Gender'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include = "object").isnull().columns:
    print(i)
# Out:
# Loan_ID
# loan_status
# effective_date
# due_date
# paid_off_time
# education
# Gender

# %%
for i in dataset.select_dtypes(include = "object").isnull().columns:
    dataset[i] = dataset[i]= dataset[i].fillna(dataset[i].mode()[0])

# %%
dataset.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# past_due_days     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %%
new_data = dataset
new_data.to_csv("cleaned_data.csv",index = False)
